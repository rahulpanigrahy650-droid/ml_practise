# %%
OPEN_AI_API = "write your api key"

# %%
#pip install openai

# %%
# prompt => openai.model => response

from openai import OpenAI

client = OpenAI(api_key = OPEN_AI_API)

response = client.responses.create(
    model = "gpt-4o",
    input = "write a short bedtime story about a unicorn"
)

print(response.output_text)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[22], line 7
#       3 from openai import OpenAI
#       5 client = OpenAI(api_key = OPEN_AI_API)
# ----> 7 response = client.responses.create(
#       8     model = "gpt-4o",
#       9     input = "write a short bedtime story about a unicorn"
#      10 )
#      12 print(response.output_text)
#
# File d:\Users\rahul\anaconda3\Lib\site-packages\openai\resources\responses\responses.py:1041, in Responses.create(self, background, context_management, conversation, include, input, instructions, max_output_tokens, max_tool_calls, metadata, model, moderation, parallel_tool_calls, previous_response_id, prompt, prompt_cache_key, prompt_cache_options, prompt_cache_retention, reasoning, safety_identifier, service_tier, store, stream, stream_options, temperature, text, tool_choice, tools, top_logprobs, top_p, truncation, user, extra_headers, extra_query, extra_body, timeout)
#    1000 def create(
#    1001     self,
#    1002     *,
#    (...)
#    1039     timeout: float | httpx2.Timeout | None | NotGiven = not_given,
#    1040 ) -> Response | Stream[ResponseStreamEvent]:
# -> 1041     return self._post(
#    1042         "/responses",
#    1043         body=maybe_transform(
#    1044             {
#    1045                 "background": background,
#    1046                 "context_management": context_management,
#    1047                 "conversation": conversation,
#    1048                 "include": include,
#    1049                 "input": input,
#    1050                 "instructions": instructions,
#    1051                 "max_output_tokens": max_output_tokens,
#    1052                 "max_tool_calls": max_tool_calls,
#    1053                 "metadata": metadata,
#    1054                 "model": model,
#    1055                 "moderation": moderation,
#    1056                 "parallel_tool_calls": parallel_tool_calls,
#    1057                 "previous_response_id": previous_response_id,
#    1058                 "prompt": prompt,
#    1059                 "prompt_cache_key": prompt_cache_key,
#    1060                 "prompt_cache_options": prompt_cache_options,
#    1061                 "prompt_cache_retention": prompt_cache_retention,
#    1062                 "reasoning": reasoning,
#    1063                 "safety_identifier": safety_identifier,
#    1064                 "service_tier": service_tier,
#    1065                 "store": store,
#    1066                 "stream": stream,
#    1067                 "stream_options": stream_options,
#    1068                 "temperature": temperature,
#    1069                 "text": text,
#    1070                 "tool_choice": tool_choice,
#    1071                 "tools": tools,
#    1072                 "top_logprobs": top_logprobs,
#    1073                 "top_p": top_p,
#    1074                 "truncation": truncation,
#    1075                 "user": user,
#    1076             },
#    1077             response_create_params.ResponseCreateParamsStreaming
#    1078             if stream
#    1079             else response_create_params.ResponseCreateParamsNonStreaming,
#    1080         ),
#    1081         options=make_request_options(
#    1082             extra_headers=extra_headers,
#    1083             extra_query=extra_query,
#    1084             extra_body=extra_body,
#    1085             timeout=timeout,
#    1086             security={"bearer_auth": True},
#    1087         ),
#    1088         cast_to=Response,
#    1089         stream=stream or False,
#    1090         stream_cls=Stream[ResponseStreamEvent],
#    1091     )
#
# File d:\Users\rahul\anaconda3\Lib\site-packages\openai\_base_client.py:1378, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1369     warnings.warn(
#    1370         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1371         "Please pass raw bytes via the `content` parameter instead.",
#    1372         DeprecationWarning,
#    1373         stacklevel=2,
#    1374     )
#    1375 opts = FinalRequestOptions.construct(
#    1376     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1377 )
# -> 1378 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File d:\Users\rahul\anaconda3\Lib\site-packages\openai\_base_client.py:1151, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1148             err.response.read()
#    1150         log.debug("Re-raising status error")
# -> 1151         raise self._make_status_error_from_response(err.response) from None
#    1153     break
#    1155 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You have no credits remaining. Add credits to continue using the API at https://platform.openai.com/settings/organization/billing/.', 'type': 'insufficient_quota', 'param': None, 'code': 'credit_balance_exhausted'}}

# %%
#pip install google-genai

# %%
from google import genai

Client = genai.Client(api_key="")
response = Client.models.generate_content(
    model = "gemini-3.6-flash",
    contents = "write a short bedtime story about a unicorn"
)

print(response.text)
# Out:
# Deep in the heart of the Velvet Forest, where the grass was softer than cotton and the streams hummed sweet lullabies, lived a little unicorn named Barnaby.
#
# Barnaby was a quiet unicorn with a coat as white as starlight and a pearly horn that glowed with a warm, cozy light—just like a bedtime nightlight.
#
# Every evening, when the sun dipped below the rolling hills and painted the sky in shades of purple and pink, it was Barnaby’s special job to help the forest go to sleep.
#
# Slowly, Barnaby began his evening walk. *Tip-tap, tip-tap* went his silver hooves, so softly that it sounded like raindrops falling on autumn leaves.
#
# First, he visited the meadow. Barnaby gently touched the tip of his glowing horn to the sleepy wildflowers. With a soft sigh, the daisies and lavender folded their petals closed, tucked in for the night.
#
# Next, he walked beneath the tall oak trees. He looked up at the little bluebirds resting in their nests. Barnaby let out a tiny, warm breath, sending a cool, lavender-scented breeze through the branches. The birds snuggled deeper into their feathers and closed their eyes.
#
# Finally, Barnaby climbed to the very top of Mossy Hill, the highest spot in the forest. He lifted his head toward the darkening sky and tapped his horn against the evening air.
#
# *Clink.*
#
# A dozen tiny silver stars blinked awake.
#
# *Clink.*
#
# A soft, glowing moon floated up into the dark blue sky, shedding a gentle, silvery blanket over the whole world.
#
# Everything in the forest was quiet now. The wind whispered, *"Hushhhhh..."* through the trees. The crickets played a slow, sleepy tune.
#
# Barnaby yawned a big, wide unicorn yawn. His legs felt heavy, and his eyelids felt even heavier. He walked over to his favorite bed of soft green moss beneath a weeping willow tree.
#
# He curled up tightly, resting his chin on his silver hooves. The bright glow of his horn slowly dimmed to a soft, sleepy pulse, like the beating of a calm heart.
#
# Barnaby closed his eyes. He took a deep breath in... and let a slow breath out.
#
# The forest was asleep, the stars were watching over him, and Barnaby drifted off into sweet, magical dreams.
#
# Goodnight, forest. Goodnight, Barnaby. Goodnight, little one.

# %%
#!pip install groq

# %%
from groq import Groq

client = Groq(api_key="")

response = client.chat.completions.create(
    model="openai/gpt-oss-20b",
    messages=[
        {"role": "user", "content": "write a short bedtime story about a unicorn"}
    ]
)

print(response.choices[0].message.content)
# Out:
# **The Moonlit Meadow and the Gentle Unicorn**
#
# Once upon a twilight hour, when the sky was a soft, buttery pink and the stars began to twinkle like tiny lanterns, a quiet meadow lay tucked beneath the sleepy arms of the forest. In that meadow lived a gentle unicorn named Liora, whose silver mane shimmered with the same glow as the moon itself.
#
# Every night, Liora would trot through the meadow, her hooves leaving a faint silver dust that made the grass sparkle like a thousand tiny moons. The meadow was her playground, but it was also her sanctuary, a place where she could dream without any worries.
#
# One night, as Liora padded by a small pond, she heard a faint whisper. It was the voice of the night breeze, soft and curious. “Liora,” it sighed, “I have seen many children in the nearby village, dreaming of adventures. Would you like to help them find a bedtime story that will bring them sweet dreams?”
#
# Liora’s eyes widened with delight. She was always eager to help. “I’ll be happy to,” she said, her voice as gentle as the wind.
#
# The unicorn leapt into the sky, her wings—though she had none—sprinkling stardust over the sleeping village below. She descended into a child’s bedroom, floating beside a little girl named Mina who had a basket of her favorite stuffed animals.
#
# Mina’s eyes fluttered open as she saw the silver glow of Liora. “Hello, unicorn,” Mina whispered. “Will you tell me a story?”
#
# Liora smiled, her eyes twinkling. “Tonight, we’ll travel to the Moonlit Meadow, a place where every wish is gently carried on a feather of moonlight,” she said.
#
# And so, the story began.
#
# *In a meadow where the grass hummed lullabies, a unicorn named Liora had a secret wish. She wanted to know how the stars felt when they were born, and she wanted to help those who dreamed.*
#
# Liora lifted her horn, which glowed with a soft, silver light. “Close your eyes, and imagine a world where stars are born from the laughter of children.” The room grew quiet, and the wind hummed a lullaby.
#
# Mina pictured the stars as tiny, bright lanterns floating in a deep, velvet sky. She saw herself, laughing, and the laughter turned into a sparkling firework that drifted upwards, turning into the smallest of stars. Liora’s story was so gentle that Mina’s breathing slowed, her eyes grew heavy.
#
# When Liora finished, the stars shone brighter, as if listening to her. “The stars love the children’s dreams,” Liora told Mina. “Because they are the light that guides you home.”
#
# Mina’s breathing steadied; her chest rose and fell like a calm tide. She felt the presence of the gentle unicorn, comforting as a warm blanket. With a smile, she whispered, “Thank you, Liora.” And she drifted off, the room filling with soft music of the night breeze and the distant chime of wind chimes.
#
# Liora, proud and content, hovered a moment longer. “Remember, little one,” she said, “when you dream, the moonlight will always guide you back to the meadow of your heart.”
#
# With a gentle sigh, the unicorn disappeared, leaving behind a faint trail of stardust. The child’s room glowed with the soft silver light that seeped through the curtains, and Mina’s dreams carried her to the Moonlit Meadow.
#
# The next morning, the girl opened her eyes, a faint smile on her face, and felt the warmth of the gentle unicorn’s story lingering like a cozy blanket.
#
# And so, every night thereafter, Liora would return to the meadow, to the pond, to the whispering wind, ready to share her gentle, dreamy tales. And every child who listened would sleep peacefully, knowing that somewhere above them, a unicorn was watching over their dreams, humming lullabies under the twinkling stars.
#
# Goodnight, dear listeners. May your dreams be as gentle and bright as a unicorn’s silver horn.

# %% [markdown]
# Roles in response api

# %%
#!pip install --upgrade openai

# %%
from groq import Groq

client = Groq(api_key="")

response = client.chat.completions.create(
    model="openai/gpt-oss-20b",
    messages=[
        {"role": "system", "content": "act like a math teacher"},
        {"role": "user", "content": "a+2=7, find a"}
    ]
)

print(response.choices[0].message.content)
# Out:
# Sure thing! Let's solve the equation step by step, just like we’d do in a math class.
#
# **Problem:**
# \[ a + 2 = 7 \]
#
# **Goal:** Find the value of \( a \).
#
# ---
#
# ### 1. Understand the equation
# You have a number \( a \) that, when you add 2 to it, gives 7. We want to isolate \( a \) on one side of the equation.
#
# ### 2. Isolate \( a \) by performing the same operation on both sides
# Since \( a \) has a \( +2 \) next to it, we undo that by subtracting 2 from both sides. This keeps the equation balanced.
#
# \[
# \begin{align*}
# a + 2 &= 7 \\
# a + 2 - 2 &= 7 - 2 \quad\text{(subtract 2 from both sides)} \\
# a &= 5
# \end{align*}
# \]
#
# ### 3. Check your answer
# Plug \( a = 5 \) back into the original equation:
#
# \[
# 5 + 2 = 7
# \]
#
# That’s correct! So, \( a = 5 \).
#
# ---
#
# **Answer:** \( a = 5 \)
#
# If you’d like to practice similar problems or explore why the steps work, just let me know!

# %% [markdown]
# send image as input

# %%
respose = client.response.create(
    model = "got-5.4",
    input = [
        {
            "role" : "user",
            "content"  : [
                {
                    "type" : "input_text",
                    "text" : "tell me the capital of the country to which flagbelongs to india"

                },
                {
                    "type" : "input_image",
                    "image_url" : "https://commons.wikimedia.org/wiki/File:Flag_of_India.png"
                }
            ]
        }
    ]
)

print(response.output_text)

# %%
from google import genai
from google.genai import types

client = genai.Client(api_key="")

response = client.models.generate_content(
    model="gemini-3.6-flash",
    contents=[
        "tell me the capital of the country to which this flag belongs",
        types.Part.from_uri(
            file_uri="https://upload.wikimedia.org/wikipedia/en/4/41/Flag_of_India.svg",
            mime_type="image/svg+xml"
        )
    ]
)

print(response.text)
# Out:
# This flag belongs to **India**, and its capital is **New Delhi**.
