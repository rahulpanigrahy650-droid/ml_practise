# %%
# !pip install langchain langchain-core langchain-community pypdf pymupdf sentence-transformers chromadb
# Out:
# Collecting langchain
#   Downloading langchain-1.4.1-py3-none-any.whl.metadata (6.2 kB)
# Collecting langchain-core
#   Using cached langchain_core-1.6.3-py3-none-any.whl.metadata (4.8 kB)
# Collecting langchain-community
#   Using cached langchain_community-0.4.2-py3-none-any.whl.metadata (3.4 kB)
# Collecting pypdf
#   Using cached pypdf-6.19.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting pymupdf
#   Using cached pymupdf-1.28.2-cp310-abi3-win_amd64.whl.metadata (26 kB)
# Collecting sentence-transformers
#   Using cached sentence_transformers-6.0.1-py3-none-any.whl.metadata (20 kB)
# Collecting chromadb
#   Using cached chromadb-1.5.9-cp39-abi3-win_amd64.whl.metadata (5.1 kB)
# Collecting langgraph<1.3.0,>=1.2.11 (from langchain)
#   Using cached langgraph-1.2.11-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\users\rahul\anaconda3\lib\site-packages (from langchain) (2.10.3)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in d:\users\rahul\anaconda3\lib\site-packages (from langchain-core) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in d:\users\rahul\anaconda3\lib\site-packages (from langchain-core) (1.33)
# Collecting langchain-protocol>=0.0.17 (from langchain-core)
#   Using cached langchain_protocol-0.0.19-py3-none-any.whl.metadata (2.4 kB)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core)
#   Downloading langsmith-0.12.6-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: packaging>=23.2.0 in d:\users\rahul\anaconda3\lib\site-packages (from langchain-core) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in d:\users\rahul\anaconda3\lib\site-packages (from langchain-core) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\users\rahul\anaconda3\lib\site-packages (from langchain-core) (9.0.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in d:\users\rahul\anaconda3\lib\site-packages (from langchain-core) (4.12.2)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core)
#   Downloading uuid_utils-0.17.1-cp313-cp313-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: anyio in d:\users\rahul\anaconda3\lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core) (4.7.0)
# Requirement already satisfied: certifi in d:\users\rahul\anaconda3\lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in d:\users\rahul\anaconda3\lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core) (1.0.9)
# Requirement already satisfied: idna in d:\users\rahul\anaconda3\lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core) (3.7)
# Requirement already satisfied: h11>=0.16 in d:\users\rahul\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in d:\users\rahul\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (2.1)
# Collecting langgraph-checkpoint<5.0.0,>=4.1.0 (from langgraph<1.3.0,>=1.2.11->langchain)
#   Using cached langgraph_checkpoint-4.2.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting langgraph-prebuilt<1.2.0,>=1.1.0 (from langgraph<1.3.0,>=1.2.11->langchain)
#   Using cached langgraph_prebuilt-1.1.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.5.0,>=0.4.2 (from langgraph<1.3.0,>=1.2.11->langchain)
#   Using cached langgraph_sdk-0.4.4-py3-none-any.whl.metadata (5.1 kB)
# Collecting xxhash>=3.5.0 (from langgraph<1.3.0,>=1.2.11->langchain)
#   Downloading xxhash-4.0.1-cp313-cp313-win_amd64.whl.metadata (18 kB)
# Collecting ormsgpack>=1.12.0 (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.11->langchain)
#   Downloading ormsgpack-1.12.2-cp313-cp313-win_amd64.whl.metadata (3.3 kB)
# Collecting orjson>=3.11.5 (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain)
#   Downloading orjson-3.12.0-cp313-cp313-win_amd64.whl.metadata (43 kB)
# Collecting websockets<17,>=14 (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain)
#   Downloading websockets-16.1.1-cp313-cp313-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: distro>=1.7.0 in d:\users\rahul\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.9.0)
# Collecting httpx2<3,>=2 (from langsmith<1.0.0,>=0.3.45->langchain-core)
#   Using cached httpx2-2.13.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\users\rahul\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in d:\users\rahul\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.32.3)
# Requirement already satisfied: sniffio>=1.1 in d:\users\rahul\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.3.0)
# Requirement already satisfied: zstandard>=0.23.0 in d:\users\rahul\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.23.0)
# Collecting anyio (from httpx<1.0.0,>=0.23.0->langchain-core)
#   Using cached anyio-4.15.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting httpcore2==2.13.0 (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core)
#   Using cached httpcore2-2.13.0-py3-none-any.whl.metadata (26 kB)
# Collecting idna (from httpx<1.0.0,>=0.23.0->langchain-core)
#   Using cached idna-3.19-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: truststore>=0.10 in d:\users\rahul\anaconda3\lib\site-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core) (0.10.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\users\rahul\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in d:\users\rahul\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in d:\users\rahul\anaconda3\lib\site-packages (from langchain-community) (3.11.10)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Using cached httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Collecting langchain-classic<2.0.0,>=1.0.7 (from langchain-community)
#   Using cached langchain_classic-1.0.8-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: numpy>=2.1.0 in d:\users\rahul\anaconda3\lib\site-packages (from langchain-community) (2.1.3)
# Collecting pydantic-settings<3.0.0,>=2.10.1 (from langchain-community)
#   Using cached pydantic_settings-2.15.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting requests>=2.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core)
#   Downloading requests-2.34.2-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in d:\users\rahul\anaconda3\lib\site-packages (from langchain-community) (2.0.39)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in d:\users\rahul\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\users\rahul\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in d:\users\rahul\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\users\rahul\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\users\rahul\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in d:\users\rahul\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in d:\users\rahul\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.18.0)
# Collecting langchain-text-splitters<2.0.0,>=1.1.2 (from langchain-classic<2.0.0,>=1.0.7->langchain-community)
#   Using cached langchain_text_splitters-1.1.2-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: python-dotenv>=0.21.0 in d:\users\rahul\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.1.0)
# Collecting typing-inspection>=0.4.0 (from pydantic-settings<3.0.0,>=2.10.1->langchain-community)
#   Using cached typing_inspection-0.4.4-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\users\rahul\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.26 in d:\users\rahul\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2.3.0)
# Requirement already satisfied: greenlet!=0.4.17 in d:\users\rahul\anaconda3\lib\site-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-community) (3.1.1)
# Collecting transformers<6.0.0,>=5.0.0 (from sentence-transformers)
#   Using cached transformers-5.17.0-py3-none-any.whl.metadata (32 kB)
# Collecting tokenizers>=0.19 (from sentence-transformers)
#   Using cached tokenizers-0.23.2-cp310-abi3-win_amd64.whl.metadata (10 kB)
# Collecting huggingface-hub<2.0.0,>=1.3.0 (from sentence-transformers)
#   Using cached huggingface_hub-1.31.0-py3-none-any.whl.metadata (16 kB)
# Collecting torch>=2.2 (from sentence-transformers)
#   Downloading torch-2.14.0-cp313-cp313-win_amd64.whl.metadata (38 kB)
# Requirement already satisfied: scikit-learn>=1.1.0 in d:\users\rahul\anaconda3\lib\site-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy>=1.0.0 in d:\users\rahul\anaconda3\lib\site-packages (from sentence-transformers) (1.15.3)
# Requirement already satisfied: tqdm>=4.0.0 in d:\users\rahul\anaconda3\lib\site-packages (from sentence-transformers) (4.67.1)
# Collecting click<9.0.0,>=8.4.2 (from huggingface-hub<2.0.0,>=1.3.0->sentence-transformers)
#   Using cached click-8.5.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: filelock>=3.10.0 in d:\users\rahul\anaconda3\lib\site-packages (from huggingface-hub<2.0.0,>=1.3.0->sentence-transformers) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\users\rahul\anaconda3\lib\site-packages (from huggingface-hub<2.0.0,>=1.3.0->sentence-transformers) (2025.3.2)
# Collecting hf-xet<2.0.0,>=1.5.2 (from huggingface-hub<2.0.0,>=1.3.0->sentence-transformers)
#   Using cached hf_xet-1.6.0-cp38-abi3-win_amd64.whl.metadata (4.9 kB)
# Collecting regex>=2025.10.22 (from transformers<6.0.0,>=5.0.0->sentence-transformers)
#   Downloading regex-2026.9.10-cp313-cp313-win_amd64.whl.metadata (41 kB)
# Requirement already satisfied: typer in d:\users\rahul\anaconda3\lib\site-packages (from transformers<6.0.0,>=5.0.0->sentence-transformers) (0.9.0)
# Collecting safetensors>=0.8.0 (from transformers<6.0.0,>=5.0.0->sentence-transformers)
#   Using cached safetensors-0.8.0-cp310-abi3-win_amd64.whl.metadata (4.2 kB)
# Collecting build>=1.0.3 (from chromadb)
#   Using cached build-1.6.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting pybase64>=1.4.1 (from chromadb)
#   Downloading pybase64-1.5.0-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached uvicorn-0.53.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Downloading onnxruntime-1.30.0-cp313-cp313-win_amd64.whl.metadata (5.9 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Using cached opentelemetry_api-1.44.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Using cached opentelemetry_exporter_otlp_proto_grpc-1.44.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Using cached opentelemetry_sdk-1.44.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting pypika>=0.48.9 (from chromadb)
#   Using cached pypika-0.51.1-py2.py3-none-any.whl.metadata (51 kB)
# Requirement already satisfied: overrides>=7.3.1 in d:\users\rahul\anaconda3\lib\site-packages (from chromadb) (7.4.0)
# Collecting importlib-resources (from chromadb)
#   Using cached importlib_resources-7.1.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting grpcio>=1.58.0 (from chromadb)
#   Downloading grpcio-1.84.0-cp313-cp313-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: bcrypt>=4.0.1 in d:\users\rahul\anaconda3\lib\site-packages (from chromadb) (4.3.0)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Using cached kubernetes-36.0.3-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Downloading mmh3-5.3.0-cp313-cp313-win_amd64.whl.metadata (14 kB)
# Requirement already satisfied: rich>=10.11.0 in d:\users\rahul\anaconda3\lib\site-packages (from chromadb) (13.9.4)
# Requirement already satisfied: jsonschema>=4.19.0 in d:\users\rahul\anaconda3\lib\site-packages (from chromadb) (4.23.0)
# Collecting typing-extensions<5.0.0,>=4.7.0 (from langchain-core)
#   Using cached typing_extensions-4.16.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Using cached pyproject_hooks-1.3.3-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: colorama in d:\users\rahul\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\users\rahul\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\users\rahul\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in d:\users\rahul\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.22.3)
# Requirement already satisfied: six>=1.9.0 in d:\users\rahul\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in d:\users\rahul\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Collecting pyyaml<7.0.0,>=5.3.0 (from langchain-core)
#   Downloading pyyaml-6.0.3-cp313-cp313-win_amd64.whl.metadata (2.4 kB)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in d:\users\rahul\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Collecting requests-oauthlib (from kubernetes>=28.1.0->chromadb)
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb)
#   Using cached durationpy-0.11-py3-none-any.whl.metadata (474 bytes)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain-community)
#   Downloading aiohttp-3.14.3-cp313-cp313-win_amd64.whl.metadata (8.5 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached aiohappyeyeballs-2.7.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting flatbuffers (from onnxruntime>=1.14.1->chromadb)
#   Using cached flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: protobuf>=4.25.8 in d:\users\rahul\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.3)
# Collecting googleapis-common-protos~=1.57 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Using cached googleapis_common_protos-1.75.3-py3-none-any.whl.metadata (8.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.44.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Using cached opentelemetry_exporter_otlp_proto_common-1.44.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.44.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Using cached opentelemetry_proto-1.44.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting protobuf>=4.25.8 (from onnxruntime>=1.14.1->chromadb)
#   Downloading protobuf-7.36.1-cp310-abi3-win_amd64.whl.metadata (595 bytes)
# Collecting opentelemetry-semantic-conventions==0.65b0 (from opentelemetry-sdk>=1.2.0->chromadb)
#   Using cached opentelemetry_semantic_conventions-0.65b0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\users\rahul\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\users\rahul\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in d:\users\rahul\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.0)
# Requirement already satisfied: joblib>=1.2.0 in d:\users\rahul\anaconda3\lib\site-packages (from scikit-learn>=1.1.0->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\users\rahul\anaconda3\lib\site-packages (from scikit-learn>=1.1.0->sentence-transformers) (3.5.0)
# Collecting setuptools>=77.0.3 (from torch>=2.2->sentence-transformers)
#   Using cached setuptools-84.0.0-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: sympy>=1.13.3 in d:\users\rahul\anaconda3\lib\site-packages (from torch>=2.2->sentence-transformers) (1.13.3)
# Requirement already satisfied: networkx>=2.5.1 in d:\users\rahul\anaconda3\lib\site-packages (from torch>=2.2->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in d:\users\rahul\anaconda3\lib\site-packages (from torch>=2.2->sentence-transformers) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\users\rahul\anaconda3\lib\site-packages (from sympy>=1.13.3->torch>=2.2->sentence-transformers) (1.3.0)
# Collecting httptools>=0.8.0 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading httptools-0.8.0-cp313-cp313-win_amd64.whl.metadata (3.7 kB)
# Collecting watchfiles>=0.20 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading watchfiles-1.2.0-cp313-cp313-win_amd64.whl.metadata (5.0 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\users\rahul\anaconda3\lib\site-packages (from jinja2->torch>=2.2->sentence-transformers) (3.0.2)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib->kubernetes>=28.1.0->chromadb)
#   Using cached oauthlib-3.3.1-py3-none-any.whl.metadata (7.9 kB)
# Downloading langchain-1.4.1-py3-none-any.whl (161 kB)
# Using cached langchain_core-1.6.3-py3-none-any.whl (571 kB)
# Using cached langgraph-1.2.11-py3-none-any.whl (248 kB)
# Using cached langgraph_checkpoint-4.2.0-py3-none-any.whl (56 kB)
# Using cached langgraph_prebuilt-1.1.0-py3-none-any.whl (41 kB)
# Using cached langgraph_sdk-0.4.4-py3-none-any.whl (162 kB)
# Downloading langsmith-0.12.6-py3-none-any.whl (768 kB)
#    ---------------------------------------- 0.0/768.5 kB ? eta -:--:--
#    ------------- -------------------------- 262.1/768.5 kB ? eta -:--:--
#    --------------------------- ------------ 524.3/768.5 kB 1.1 MB/s eta 0:00:01
#    --------------------------- ------------ 524.3/768.5 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 768.5/768.5 kB 1.1 MB/s eta 0:00:00
# Using cached httpx2-2.13.0-py3-none-any.whl (95 kB)
# Using cached httpcore2-2.13.0-py3-none-any.whl (83 kB)
# Downloading uuid_utils-0.17.1-cp313-cp313-win_amd64.whl (175 kB)
# Downloading websockets-16.1.1-cp313-cp313-win_amd64.whl (180 kB)
# Using cached langchain_community-0.4.2-py3-none-any.whl (2.4 MB)
# Using cached httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Using cached langchain_classic-1.0.8-py3-none-any.whl (1.0 MB)
# Using cached langchain_text_splitters-1.1.2-py3-none-any.whl (35 kB)
# Using cached pydantic_settings-2.15.0-py3-none-any.whl (69 kB)
# Downloading requests-2.34.2-py3-none-any.whl (73 kB)
# Using cached idna-3.19-py3-none-any.whl (68 kB)
# Using cached pypdf-6.19.0-py3-none-any.whl (395 kB)
# Using cached pymupdf-1.28.2-cp310-abi3-win_amd64.whl (19.8 MB)
# Using cached sentence_transformers-6.0.1-py3-none-any.whl (739 kB)
# Using cached huggingface_hub-1.31.0-py3-none-any.whl (798 kB)
# Using cached click-8.5.0-py3-none-any.whl (125 kB)
# Using cached hf_xet-1.6.0-cp38-abi3-win_amd64.whl (4.0 MB)
# Using cached transformers-5.17.0-py3-none-any.whl (12.3 MB)
# Using cached tokenizers-0.23.2-cp310-abi3-win_amd64.whl (2.9 MB)
# Using cached chromadb-1.5.9-cp39-abi3-win_amd64.whl (23.5 MB)
# Using cached anyio-4.15.1-py3-none-any.whl (132 kB)
# Using cached typing_extensions-4.16.0-py3-none-any.whl (45 kB)
# Using cached build-1.6.1-py3-none-any.whl (31 kB)
# Downloading grpcio-1.84.0-cp313-cp313-win_amd64.whl (5.3 MB)
#    ---------------------------------------- 0.0/5.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/5.3 MB ? eta -:--:--
#    ----- ---------------------------------- 0.8/5
MB 2.5 MB/s eta 0:00:11
#    ------------------------------- -------- 98.6/124.1 MB 2.5 MB/s eta 0:00:11
#    -------------------------------- ------- 99.6/124.1 MB 2.5 MB/s eta 0:00:10
#    -------------------------------- ------- 100.1/124.1 MB 2.5 MB/s eta 0:00:10
#    -------------------------------- ------- 100.9/124.1 MB 2.5 MB/s eta 0:00:10
#    -------------------------------- ------- 101.2/124.1 MB 2.5 MB/s eta 0:00:10
#    -------------------------------- ------- 101.2/124.1 MB 2.5 MB/s eta 0:00:10
#    -------------------------------- ------- 101.7/124.1 MB 2.5 MB/s eta 0:00:09
#    -------------------------------- ------- 102.2/124.1 MB 2.5 MB/s eta 0:00:09
#    --------------------------------- ------ 103.0/124.1 MB 2.5 MB/s eta 0:00:09
#    --------------------------------- ------ 103.5/124.1 MB 2.5 MB/s eta 0:00:09
#    --------------------------------- ------ 104.3/124.1 MB 2.6 MB/s eta 0:00:08
#    --------------------------------- ------ 105.1/124.1 MB 2.6 MB/s eta 0:00:08
#    ---------------------------------- ----- 105.9/124.1 MB 2.6 MB/s eta 0:00:08
#    ---------------------------------- ----- 106.4/124.1 MB 2.6 MB/s eta 0:00:07
#    ---------------------------------- ----- 107.2/124.1 MB 2.6 MB/s eta 0:00:07
#    ---------------------------------- ----- 108.0/124.1 MB 2.6 MB/s eta 0:00:07
#    ----------------------------------- ---- 108.8/124.1 MB 2.6 MB/s eta 0:00:06
#    ----------------------------------- ---- 109.6/124.1 MB 2.6 MB/s eta 0:00:06
#    ----------------------------------- ---- 110.1/124.1 MB 2.7 MB/s eta 0:00:06
#    ----------------------------------- ---- 110.9/124.1 MB 2.7 MB/s eta 0:00:05
#    ----------------------------------- ---- 111.4/124.1 MB 2.7 MB/s eta 0:00:05
#    ------------------------------------ --- 112.2/124.1 MB 2.7 MB/s eta 0:00:05
#    ------------------------------------ --- 112.7/124.1 MB 2.7 MB/s eta 0:00:05
#    ------------------------------------ --- 113.5/124.1 MB 2.7 MB/s eta 0:00:04
#    ------------------------------------ --- 114.0/124.1 MB 2.7 MB/s eta 0:00:04
#    ------------------------------------- -- 114.8/124.1 MB 2.7 MB/s eta 0:00:04
#    ------------------------------------- -- 115.9/124.1 MB 2.7 MB/s eta 0:00:04
#    ------------------------------------- -- 116.4/124.1 MB 2.7 MB/s eta 0:00:03
#    ------------------------------------- -- 117.2/124.1 MB 2.8 MB/s eta 0:00:03
#    -------------------------------------- - 118.0/124.1 MB 2.8 MB/s eta 0:00:03
#    -------------------------------------- - 118.8/124.1 MB 2.8 MB/s eta 0:00:02
#    -------------------------------------- - 119.0/124.1 MB 2.8 MB/s eta 0:00:02
#    -------------------------------------- - 119.8/124.1 MB 2.8 MB/s eta 0:00:02
#    -------------------------------------- - 120.6/124.1 MB 2.8 MB/s eta 0:00:02
#    ---------------------------------------  121.1/124.1 MB 2.8 MB/s eta 0:00:02
#    ---------------------------------------  121.9/124.1 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------  122.7/124.1 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------  123.2/124.1 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------  124.0/124.1 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------  124.0/124.1 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------  124.0/124.1 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------  124.0/124.1 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------  124.0/124.1 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 124.1/124.1 MB 2.8 MB/s eta 0:00:00
# Using cached setuptools-84.0.0-py3-none-any.whl (818 kB)
# Using cached typing_inspection-0.4.4-py3-none-any.whl (14 kB)
# Using cached uvicorn-0.53.0-py3-none-any.whl (87 kB)
# Downloading httptools-0.8.0-cp313-cp313-win_amd64.whl (90 kB)
# Downloading watchfiles-1.2.0-cp313-cp313-win_amd64.whl (288 kB)
# Downloading xxhash-4.0.1-cp313-cp313-win_amd64.whl (36 kB)
# Using cached flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Using cached importlib_resources-7.1.0-py3-none-any.whl (37 kB)
# Using cached pyproject_hooks-1.3.3-py3-none-any.whl (10 kB)
# Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Using cached oauthlib-3.3.1-py3-none-any.whl (160 kB)
# Installing collected packages: pypika, flatbuffers, durationpy, xxhash, websockets, uuid-utils, typing-extensions, setuptools, safetensors, regex, pyyaml, pyproject_hooks, pypdf, pymupdf, pybase64, protobuf, ormsgpack, orjson, oauthlib, mmh3, importlib-resources, idna, httpx-sse, httptools, httpcore2, hf-xet, click, aiosignal, aiohappyeyeballs, uvicorn, typing-inspection, torch, requests, opentelemetry-proto, opentelemetry-api, onnxruntime, langchain-protocol, grpcio, googleapis-common-protos, build, anyio, watchfiles, requests-oauthlib, opentelemetry-semantic-conventions, opentelemetry-exporter-otlp-proto-common, httpx2, aiohttp, pydantic-settings, opentelemetry-sdk, langsmith, kubernetes, huggingface-hub, tokenizers, opentelemetry-exporter-otlp-proto-grpc, langchain-core, transformers, langgraph-sdk, langgraph-checkpoint, langchain-text-splitters, chromadb, sentence-transformers, langgraph-prebuilt, langchain-classic, langgraph, langchain-community, langchain
#
#    ----------------------------------------  0/66 [pypika]
#    ----------------------------------------  0/66 [pypika]
#     ---------------------------------------  1/66 [flatbuffers]
#     ---------------------------------------  1/66 [flatbuffers]
#    -- -------------------------------------  4/66 [websockets]
#    -- -------------------------------------  4/66 [websockets]
#    -- -------------------------------------  4/66 [websockets]
#    -- -------------------------------------  4/66 [websockets]
#    -- -------------------------------------  4/66 [websockets]
#   Attempting uninstall: typing-extensions
#    -- -------------------------------------  4/66 [websockets]
#     Found existing installation: typing_extensions 4.12.2
#    -- -------------------------------------  4/66 [websockets]
#     Uninstalling typing_extensions-4.12.2:
#    -- -------------------------------------  4/66 [websockets]
#    --- ------------------------------------  6/66 [typing-extensions]
#    --- ------------------------------------  6/66 [typing-extensions]
#    --- ------------------------------------  6/66 [typing-extensions]
#    --- ------------------------------------  6/66 [typing-extensions]
#    --- ------------------------------------  6/66 [typing-extensions]
#    --- ------------------------------------  6/66 [typing-extensions]
#    --- ------------------------------------  6/66 [typing-extensions]
#    --- ------------------------------------  6/66 [typing-extensions]
#    --- ------------------------------------  6/66 [typing-extensions]
#    --- ------------------------------------  6/66 [typing-extensions]
#    --- ------------------------------------  6/66 [typing-extensions]
#    --- ------------------------------------  6/66 [typing-extensions]
#    --- ------------------------------------  6/66 [typing-extensions]
#    --- ------------------------------------  6/66 [typing-extensions]
#    --- ------------------------------------  6/66 [typing-extensions]
# ...
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    ------------------------------------- -- 62/66 [langchain-classic]
#    -------------------------------------- - 63/66 [langgraph]
#    -------------------------------------- - 63/66 [langgraph]
#    -------------------------------------- - 63/66 [langgraph]
#    -------------------------------------- - 63/66 [langgraph]
#    -------------------------------------- - 63/66 [langgraph]
#    -------------------------------------- - 63/66 [langgraph]
#    -------------------------------------- - 63/66 [langgraph]
#    -------------------------------------- - 63/66 [langgraph]
#    -------------------------------------- - 63/66 [langgraph]
#    -------------------------------------- - 63/66 [langgraph]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    -------------------------------------- - 64/66 [langchain-community]
#    ---------------------------------------  65/66 [langchain]
#    ---------------------------------------  65/66 [langchain]
#    ---------------------------------------  65/66 [langchain]
#    ---------------------------------------  65/66 [langchain]
#    ---------------------------------------- 66/66 [langchain]
#
# Successfully installed aiohappyeyeballs-2.7.1 aiohttp-3.14.3 aiosignal-1.4.0 anyio-4.15.1 build-1.6.1 chromadb-1.5.9 click-8.5.0 durationpy-0.11 flatbuffers-25.12.19 googleapis-common-protos-1.75.3 grpcio-1.84.0 hf-xet-1.6.0 httpcore2-2.13.0 httptools-0.8.0 httpx-sse-0.4.3 httpx2-2.13.0 huggingface-hub-1.31.0 idna-3.19 importlib-resources-7.1.0 kubernetes-36.0.3 langchain-1.4.1 langchain-classic-1.0.8 langchain-community-0.4.2 langchain-core-1.6.3 langchain-protocol-0.0.19 langchain-text-splitters-1.1.2 langgraph-1.2.11 langgraph-checkpoint-4.2.0 langgraph-prebuilt-1.1.0 langgraph-sdk-0.4.4 langsmith-0.12.6 mmh3-5.3.0 oauthlib-3.3.1 onnxruntime-1.30.0 opentelemetry-api-1.44.0 opentelemetry-exporter-otlp-proto-common-1.44.0 opentelemetry-exporter-otlp-proto-grpc-1.44.0 opentelemetry-proto-1.44.0 opentelemetry-sdk-1.44.0 opentelemetry-semantic-conventions-0.65b0 orjson-3.12.0 ormsgpack-1.12.2 protobuf-7.36.1 pybase64-1.5.0 pydantic-settings-2.15.0 pymupdf-1.28.2 pypdf-6.19.0 pypika-0.51.1 pyproject_hooks-1.3.3 pyyaml-6.0.3 regex-2026.9.10 requests-2.34.2 requests-oauthlib-2.0.0 safetensors-0.8.0 sentence-transformers-6.0.1 setuptools-84.0.0 tokenizers-0.23.2 torch-2.14.0 transformers-5.17.0 typing-extensions-4.16.0 typing-inspection-0.4.4 uuid-utils-0.17.1 uvicorn-0.53.0 watchfiles-1.2.0 websockets-16.1.1 xxhash-4.0.1

# %%
from langchain_core.documents import Document

# %%
sample_doc = Document(
    page_content="Hello World!",
    metadata={"source": "https://www.google.com"}
)

# %%
sample_doc
# Out:
# Document(metadata={'source': 'https://www.google.com'}, page_content='Hello World!')

# %%
type(sample_doc)
# Out:
# langchain_core.documents.base.Document

# %%
# Text data
from langchain_community.document_loaders.text import TextLoader

loader = TextLoader("data/Python.txt", encoding="utf-8")
# Out:
# C:\Users\rahul\AppData\Local\Temp\ipykernel_22672\2888318756.py:2: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders.text import TextLoader

# %%
document = loader.load()

# %%
document
# Out:
# [Document(metadata={'source': 'data/Python.txt'}, page_content='Python is a high-level, interpreted programming language that has become one of the most popular and widely used languages in the world. Created by Guido van Rossum and first released in 1991, Python emphasizes simplicity and readability, making it easy for beginners to learn while remaining powerful for experienced developers. Its clean and concise syntax allows programmers to write fewer lines of code compared to many other languages, enhancing productivity and maintainability. Python supports multiple programming paradigms, including procedural, object-oriented, and functional programming, which makes it versatile for a wide range of applications.\nSome key features and benefits of Python include:\n\n- Ease of Learning: Simple syntax and readability make Python beginner-friendly.\n- Versatility: Suitable for web development, data analysis, artificial intelligence, machine learning, scientific computing, automation, and more.\n- Extensive Libraries and Frameworks: Libraries like NumPy, Pandas, Matplotlib, and frameworks like Django and Flask accelerate development.\n- Cross-Platform Compatibility: Python programs can run on Windows, macOS, Linux, and other platforms without major modifications.\n- Strong Community Support: A large and active community provides extensive documentation, tutorials, and open-source resources.\n- Integration Capabilities: Python can integrate with other languages like C/C++, Java, and supports REST APIs, databases, and cloud services.\n- Rapid Prototyping: Python allows for quick development and testing of ideas due to its interpreted nature and ease of use.\n  Python’s combination of simplicity, flexibility, and a rich ecosystem makes it a top choice for developers, researchers, and enterprises worldwide, whether building small scripts or complex, large-scale applications.\n')]

# %%
# # PDF data
# from langchain_community.document_loaders.pdf import PyPDFLoader

# pdf_loader = PyPDFLoader("data/research.pdf")

# document = pdf_loader.load()
# document

# %%
# # PDF data
# from langchain_community.document_loaders.pdf import PyMuPDFLoader

# pdf_loader = PyMuPDFLoader("data/research.pdf")

# document = pdf_loader.load()
# document

# %% [markdown]
# ## Ingestion Pipeline

# %%
# Data => Documents
import os
from langchain_community.document_loaders.pdf import PyPDFLoader

# %% [markdown]
# ### Documents

# %%
def load_all_pdfs():
    folder_path = "data/pdfs"
    num_docs = 0
    all_docs = []

    for filename in os.listdir(folder_path):
        if filename.lower().endswith(".pdf"):
            # complete file path
            pdf_path = os.path.join(folder_path, filename)

            loader = PyPDFLoader(pdf_path)
            doc = loader.load()
            
            all_docs.extend(doc)
            num_docs += 1

    print("total pdfs:", num_docs)
    print("total pages:", len(all_docs))
    return all_docs

# %%
all_pdf_documents = load_all_pdfs()
# Out:
# total pdfs: 2
# total pages: 32

# %%
type(all_pdf_documents[1])
# Out:
# langchain_core.documents.base.Document

# %% [markdown]
# ### Chunks

# %%
# chunks
# !pip install langchain_text_splitters

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

def split_docs(documents, chunk_size=500, chunk_overlap=50):
    
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size = chunk_size,
        chunk_overlap = chunk_overlap
    )

    chunked_docs = text_splitter.split_documents(documents)
    return chunked_docs

# %%
chunks = split_docs(all_pdf_documents)

# %%
len(chunks)
# Out:
# 321

# %% [markdown]
# ### Embedding

# %%
from sentence_transformers import SentenceTransformer

# %%
class EmbeddingManager:
    def __init__(self, model_name="all-MiniLM-L6-v2"):
        
        self.model_name=model_name
        print("loading model....", self.model_name)
        self.model = SentenceTransformer(self.model_name)
        print("embedding dimensions=", self.model.get_sentence_embedding_dimension())


    def generate_embeddings(self, text):
        embeddings = self.model.encode(text, show_progress_bar=True)
        print("embeddings shape:", embeddings.shape)
        return embeddings

# %%
embedding_manager = EmbeddingManager()
# Out:
# loading model.... all-MiniLM-L6-v2
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# embedding dimensions= 384
# C:\Users\rahul\AppData\Local\Temp\ipykernel_22672\4021223045.py:7: FutureWarning: The `get_sentence_embedding_dimension` method has been renamed to `get_embedding_dimension`.
#   print("embedding dimensions=", self.model.get_sentence_embedding_dimension())

# %% [markdown]
# ### Vector Store

# %%
import chromadb
import uuid

# %%
class VectorStoreManager:
    def __init__(self, persist_directory="data/vector_store", collection_name="pdf_documents"):
        self.collection_name = collection_name
        self.persist_directory = persist_directory
        self.collection = None
        self.client = None

        self._initialize_store()

    def _initialize_store(self):
        os.makedirs(self.persist_directory, exist_ok=True)
        
        # create a client
        self.client = chromadb.PersistentClient(path=self.persist_directory)

        # create the collection
        self.collection = self.client.get_or_create_collection(
            name=self.collection_name,
            metadata={"description": "vector store collection for pdf embeddings in RAG"}
        )

        print("initialized the vector store with collection:", self.collection_name)
        print("docs in collection:", self.collection.count())

    def add_documents(self, documents, embeddings):
        if len(documents) != len(embeddings):
            raise ValueError("num of documents does not match num of embeddings")


        # store => ids, embedding, document, metadata
        ids = []
        all_metadata = []
        documents_content = []
        embeddings_list = []

        for i, (doc, embedding) in enumerate(zip(documents, embeddings)):
            doc_id = f"doc_{uuid.uuid4()}"
            ids.append(doc_id)

            metadata = dict(doc.metadata)
            metadata["doc_index"] = i
            metadata["content_length"] = len(doc.page_content)
            all_metadata.append(metadata)

            documents_content.append(doc.page_content)

            embeddings_list.append(embedding.tolist())

            self.collection.add(
                ids=ids,
                metadatas=all_metadata,
                documents=documents_content,
                embeddings=embeddings_list
            )

        print("total documents added in vector store=", len(documents_content))
        print("docs in collection:", self.collection.count())

# %%
vector_store = VectorStoreManager()
# Out:
# initialized the vector store with collection: pdf_documents
# docs in collection: 0

# %%
# data => documents => chunks => embeddings => store in vector store

texts = [doc.page_content for doc in chunks]

emebedding = embedding_manager.generate_embeddings(texts)

vector_store.add_documents(chunks, emebedding)
# Out:
# Batches:   0%|          | 0/11 [00:00<?, ?it/s]
# embeddings shape: (321, 384)
# total documents added in vector store= 321
# docs in collection: 321

# %% [markdown]
# # Retrieval Pipeline

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
class RAGRetriever:
    def __init__(self, embedding_manager, vector_store):
        self.embedding_manager = embedding_manager
        self.vector_store = vector_store


    def retrieve(self, query, top_k=5, score_threshold=0.0):
        # query => embedding
        query_embeddings = self.embedding_manager.generate_embeddings([query])[0]

        # semantic search
        results = self.vector_store.collection.query(
            query_embeddings=[query_embeddings.tolist()],
            n_results=top_k
        )

        # cosine similarity
        retrieved_docs=[]
        
        if results["documents"] and results["documents"][0]:
            ids = results["ids"][0]
            metadatas = results["metadatas"][0]
            documents = results["documents"][0]
            distances = results["distances"][0]

            for i, (doc_id, metadata, document, distance) in enumerate(zip(ids, metadatas, documents, distances)):
                similarity_score = 1 - distance

                if similarity_score >= score_threshold:
                    retrieved_docs.append({
                        "id": doc_id,
                        "document": document,
                        "metadata": metadata,
                        "distance": distance,
                        "similarity_score": similarity_score,
                        "rank" : i + 1
                    })

            print(f"retrieved {len(retrieved_docs)} documents")

        else:
            print("no documents found")

        return retrieved_docs

# %%
rag_retriever = RAGRetriever(embedding_manager, vector_store)

# %%
rag_retriever.retrieve("What is encoder decoder")
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# embeddings shape: (1, 384)
# retrieved 4 documents
# [{'id': 'doc_b894e8cb-f1d2-4a01-b556-22788c4f2386',
#   'document': 'positional encodings in both the encoder and decoder stacks. For the base model, we use a rate of\nPdrop = 0.1.\n7\nprabhupritampradhan4@gmail.com',
#   'metadata': {'lastpage': '6008',
#    'description-abstract': 'The dominant sequence transduction models are based on complex recurrent orconvolutional neural networks in an encoder and decoder configuration. The best performing such models also connect the encoder and decoder through an attentionm echanisms.  We propose a novel, simple network architecture based solely onan attention mechanism, dispensing with recurrence and convolutions entirely.Experiments on two machine translation tasks show these models to be superiorin quality while being more parallelizable and requiring significantly less timeto train. Our single model with 165 million parameters, achieves 27.5 BLEU onEnglish-to-German translation, improving over the existing best ensemble result by over 1 BLEU. On English-to-French translation, we outperform the previoussingle state-of-the-art with model by 0.7 BLEU, achieving a BLEU score of 41.1.',
#    'created': '2017',
#    'moddate': '2026-09-16T18:23:41+00:00',
#    'eventtype': 'Poster',
#    'producer': 'pdfcpu v0.12.1 dev',
#    'language': 'en-US',
#    'subject': 'Neural Information Processing Systems http://nips.cc/',
#    'editors': 'I. Guyon and U.V. Luxburg and S. Bengio and H. Wallach and R. Fergus and S. Vishwanathan and R. Garnett',
#    'description': 'Paper accepted and presented at the Neural Information Processing Systems Conference (http://nips.cc/)',
#    'publisher': 'Curran Associates, Inc.',
#    'doc_index': 50,
#    'source': 'data/pdfs\\research1.pdf',
#    'total_pages': 11,
#    'type': 'Conference Proceedings',
#    'firstpage': '5998',
#    'creator': 'PyPDF',
#    'content_length': 143,
#    'page_label': '7',
#    'date': '2017',
#    'creationdate': '2026-09-16T18:23:41+00:00',
#    'book': 'Advances in Neural Information Processing Systems 30',
#    'page': 6,
#    'title': 'Attention is All you Need',
#    'author': 'Ashish Vaswani, Noam Shazeer, Niki Parmar, Jakob Uszkoreit, Llion Jones, Aidan N. Gomez, Łukasz Kaiser, Illia Polosukhin',
#    'published': '2017'},
#   'distance': 0.7655773758888245,
#   'similarity_score': 0.23442262411117554,
#   'rank': 1},
#  {'id': 'doc_bd67cdaa-5763-4226-b374-1a89616ea4eb',
#   'document': 'layers, produce outputs of dimensiondmodel = 512.\nDecoder: The decoder is also composed of a stack ofN = 6 identical layers. In addition to the two\nsub-layers in each encoder layer, the decoder inserts a third sub-layer, which performs multi-head\nattention over the output of the encoder stack. Similar to the encoder, we employ residual connections\naround each of the sub-layers, followed by layer normalization. We also modify the self-attention',
#   'metadata': {'subject': 'Neural Information Processing Systems http://nips.cc/',
#    'page_label': '3',
#    'description': 'Paper accepted and presented at the Neural Information Processing Systems Conference (http://nips.cc/)',
#    'content_length': 447,
#    'doc_index': 18,
#    'eventtype': 'Poster',
#    'type': 'Conference Proceedings',
#    'published': '2017',
#    'firstpage': '5998',
#    'author': 'Ashish Vaswani, Noam Shazeer, Niki Parmar, Jakob Uszkoreit, Llion Jones, Aidan N. Gomez, Łukasz Kaiser, Illia Polosukhin',
#    'editors': 'I. Guyon and U.V. Luxburg and S. Bengio and H. Wallach and R. Fergus and S. Vishwanathan and R. Garnett',
#    'lastpage': '6008',
#    'page': 2,
#    'title': 'Attention is All you Need',
#    'source': 'data/pdfs\\research1.pdf',
#    'book': 'Advances in Neural Information Processing Systems 30',
#    'total_pages': 11,
#    'creationdate': '2026-09-16T18:23:41+00:00',
#    'description-abstract': 'The dominant sequence transduction models are based on complex recurrent orconvolutional neural networks in an encoder and decoder configuration. The best performing such models also connect the encoder and decoder through an attentionm echanisms.  We propose a novel, simple network architecture based solely onan attention mechanism, dispensing with recurrence and convolutions entirely.Experiments on two machine translation tasks show these models to be superiorin quality while being more parallelizable and requiring significantly less timeto train. Our single model with 165 million parameters, achieves 27.5 BLEU onEnglish-to-German translation, improving over the existing best ensemble result by over 1 BLEU. On English-to-French translation, we outperform the previoussingle state-of-the-art with model by 0.7 BLEU, achieving a BLEU score of 41.1.',
#    'creator': 'PyPDF',
#    'language': 'en-US',
#    'producer': 'pdfcpu v0.12.1 dev',
#    'created': '2017',
#    'date': '2017',
#    'moddate': '2026-09-16T18:23:41+00:00',
#    'publisher': 'Curran Associates, Inc.'},
#   'distance': 0.7845931649208069,
#   'similarity_score': 0.21540683507919312,
#   'rank': 2},
#  {'id': 'doc_57feca51-0643-4272-91c5-a4bbaa189f9f',
#   'document': 'respectively.\n3.1 Encoder and Decoder Stacks\nEncoder: The encoder is composed of a stack of N = 6 identical layers. Each layer has two\nsub-layers. The ﬁrst is a multi-head self-attention mechanism, and the second is a simple, position-\n2\nprabhupritampradhan4@gmail.com',
#   'metadata': {'title': 'Attention is All you Need',
#    'type': 'Conference Proceedings',
#    'content_length': 268,
#    'description-abstract': 'The dominant sequence transduction models are based on complex recurrent orconvolutional neural networks in an encoder and decoder configuration. The best performing such models also connect the encoder and decoder through an attentionm echanisms.  We propose a novel, simple network architecture based solely onan attention mechanism, dispensing with recurrence and convolutions entirely.Experiments on two machine translation tasks show these models to be superiorin quality while being more parallelizable and requiring significantly less timeto train. Our single model with 165 million parameters, achieves 27.5 BLEU onEnglish-to-German translation, improving over the existing best ensemble result by over 1 BLEU. On English-to-French translation, we outperform the previoussingle state-of-the-art with model by 0.7 BLEU, achieving a BLEU score of 41.1.',
#    'publisher': 'Curran Associates, Inc.',
#    'editors': 'I. Guyon and U.V. Luxburg and S. Bengio and H. Wallach and R. Fergus and S. Vishwanathan and R. Garnett',
#    'page': 1,
#    'source': 'data/pdfs\\research1.pdf',
#    'date': '2017',
#    'published': '2017',
#    'author': 'Ashish Vaswani, Noam Shazeer, Niki Parmar, Jakob Uszkoreit, Llion Jones, Aidan N. Gomez, Łukasz Kaiser, Illia Polosukhin',
#    'eventtype': 'Poster',
#    'firstpage': '5998',
#    'creationdate': '2026-09-16T18:23:41+00:00',
#    'subject': 'Neural Information Processing Systems http://nips.cc/',
#    'page_label': '2',
#    'total_pages': 11,
#    'created': '2017',
#    'lastpage': '6008',
#    'producer': 'pdfcpu v0.12.1 dev',
#    'moddate': '2026-09-16T18:23:41+00:00',
#    'doc_index': 16,
#    'description': 'Paper accepted and presented at the Neural Information Processing Systems Conference (http://nips.cc/)',
#    'book': 'Advances in Neural Information Processing Systems 30',
#    'creator': 'PyPDF',
#    'language': 'en-US'},
#   'distance': 0.8378260135650635,
#   'similarity_score': 0.16217398643493652,
#   'rank': 3},
#  {'id': 'doc_1c90c070-eb53-4149-8431-0b9c6e038d2e',
#   'document': '[31, 2, 8].\n• The encoder contains self-attention layers. In a self-attention layer all of the keys, values\nand queries come from the same place, in this case, the output of the previous layer in the\nencoder. Each position in the encoder can attend to all positions in the previous layer of the\nencoder.\n• Similarly, self-attention layers in the decoder allow each position in the decoder to attend to\nall positions in the decoder up to and including that position. We need to prevent leftward',
#   'metadata': {'creationdate': '2026-09-16T18:23:41+00:00',
#    'source': 'data/pdfs\\research1.pdf',
#    'editors': 'I. Guyon and U.V. Luxburg and S. Bengio and H. Wallach and R. Fergus and S. Vishwanathan and R. Garnett',
#    'lastpage': '6008',
#    'page': 4,
#    'subject': 'Neural Information Processing Systems http://nips.cc/',
#    'publisher': 'Curran Associates, Inc.',
#    'total_pages': 11,
#    'producer': 'pdfcpu v0.12.1 dev',
#    'page_label': '5',
#    'content_length': 493,
#    'date': '2017',
#    'title': 'Attention is All you Need',
#    'type': 'Conference Proceedings',
#    'book': 'Advances in Neural Information Processing Systems 30',
#    'doc_index': 29,
#    'firstpage': '5998',
#    'description-abstract': 'The dominant sequence transduction models are based on complex recurrent orconvolutional neural networks in an encoder and decoder configuration. The best performing such models also connect the encoder and decoder through an attentionm echanisms.  We propose a novel, simple network architecture based solely onan attention mechanism, dispensing with recurrence and convolutions entirely.Experiments on two machine translation tasks show these models to be superiorin quality while being more parallelizable and requiring significantly less timeto train. Our single model with 165 million parameters, achieves 27.5 BLEU onEnglish-to-German translation, improving over the existing best ensemble result by over 1 BLEU. On English-to-French translation, we outperform the previoussingle state-of-the-art with model by 0.7 BLEU, achieving a BLEU score of 41.1.',
#    'language': 'en-US',
#    'published': '2017',
#    'creator': 'PyPDF',
#    'author': 'Ashish Vaswani, Noam Shazeer, Niki Parmar, Jakob Uszkoreit, Llion Jones, Aidan N. Gomez, Łukasz Kaiser, Illia Polosukhin',
#    'eventtype': 'Poster',
#    'description': 'Paper accepted and presented at the Neural Information Processing Systems Conference (http://nips.cc/)',
#    'moddate': '2026-09-16T18:23:41+00:00',
#    'created': '2017'},
#   'distance': 0.89743572473526,
#   'similarity_score': 0.10256427526473999,
#   'rank': 4}]

# %% [markdown]
# OpenAi - Gpt

# %%
API_KEY_OPENAI =  ""

# %%
# !pip install langchain-openai
# Out:
# Collecting langchain-openai
#   Using cached langchain_openai-1.6.2-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: certifi>=2024.6.2 in d:\users\rahul\anaconda3\lib\site-packages (from langchain-openai) (2025.11.12)
# Requirement already satisfied: langchain-core<2.0.0,>=1.6.2 in d:\users\rahul\anaconda3\lib\site-packages (from langchain-openai) (1.6.3)
# Collecting openai<4.0.0,>=2.45.0 (from langchain-openai)
#   Downloading openai-3.16.1-py3-none-any.whl.metadata (43 kB)
# Collecting tiktoken<1.0.0,>=0.7.0 (from langchain-openai)
#   Downloading tiktoken-0.14.0-cp313-cp313-win_amd64.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in d:\users\rahul\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.6.2->langchain-openai) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in d:\users\rahul\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.6.2->langchain-openai) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in d:\users\rahul\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.6.2->langchain-openai) (0.0.19)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in d:\users\rahul\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.6.2->langchain-openai) (0.12.6)
# Requirement already satisfied: packaging>=23.2.0 in d:\users\rahul\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.6.2->langchain-openai) (24.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\users\rahul\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.6.2->langchain-openai) (2.10.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in d:\users\rahul\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.6.2->langchain-openai) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\users\rahul\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.6.2->langchain-openai) (9.0.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in d:\users\rahul\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.6.2->langchain-openai) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in d:\users\rahul\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.6.2->langchain-openai) (0.17.1)
# Requirement already satisfied: anyio in d:\users\rahul\anaconda3\lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.2->langchain-openai) (4.15.1)
# Requirement already satisfied: httpcore==1.* in d:\users\rahul\anaconda3\lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.2->langchain-openai) (1.0.9)
# Requirement already satisfied: idna in d:\users\rahul\anaconda3\lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.2->langchain-openai) (3.19)
# Requirement already satisfied: h11>=0.16 in d:\users\rahul\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.2->langchain-openai) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in d:\users\rahul\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.6.2->langchain-openai) (2.1)
# Requirement already satisfied: distro>=1.7.0 in d:\users\rahul\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.2->langchain-openai) (1.9.0)
# Requirement already satisfied: httpx2<3,>=2 in d:\users\rahul\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.2->langchain-openai) (2.13.0)
# Requirement already satisfied: orjson>=3.9.14 in d:\users\rahul\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.2->langchain-openai) (3.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\users\rahul\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.2->langchain-openai) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in d:\users\rahul\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.2->langchain-openai) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in d:\users\rahul\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.2->langchain-openai) (1.3.0)
# Requirement already satisfied: websockets>=15.0 in d:\users\rahul\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.2->langchain-openai) (16.1.1)
# Requirement already satisfied: xxhash>=3.0.0 in d:\users\rahul\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.2->langchain-openai) (4.0.1)
# Requirement already satisfied: zstandard>=0.23.0 in d:\users\rahul\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.2->langchain-openai) (0.23.0)
# Requirement already satisfied: httpcore2==2.13.0 in d:\users\rahul\anaconda3\lib\site-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.2->langchain-openai) (2.13.0)
# Requirement already satisfied: truststore>=0.10 in d:\users\rahul\anaconda3\lib\site-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.2->langchain-openai) (0.10.0)
# Collecting jiter<1,>=0.16.0 (from openai<4.0.0,>=2.45.0->langchain-openai)
#   Downloading jiter-0.17.0-cp313-cp313-win_amd64.whl.metadata (5.3 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\users\rahul\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.6.2->langchain-openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in d:\users\rahul\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.6.2->langchain-openai) (2.27.1)
# Requirement already satisfied: regex in d:\users\rahul\anaconda3\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2026.9.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\users\rahul\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.2->langchain-openai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.26 in d:\users\rahul\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.2->langchain-openai) (2.3.0)
# Using cached langchain_openai-1.6.2-py3-none-any.whl (125 kB)
# Downloading openai-3.16.1-py3-none-any.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.1 MB ? eta -:--:--
#    ---------- ----------------------------- 0.5/2.1 MB 974.3 kB/s eta 0:00:02
#    --------------- ------------------------ 0.8/2.1 MB 1.1 MB/s eta 0:00:02
#    -------------------- ------------------- 1.0/2.1 MB 1.2 MB/s eta 0:00:01
#    ------------------------- -------------- 1.3/2.1 MB 1.1 MB/s eta 0:00:01
#    ------------------------------ --------- 1.6/2.1 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 1.2 MB/s eta 0:00:00
# Downloading jiter-0.17.0-cp313-cp313-win_amd64.whl (226 kB)
# Downloading tiktoken-0.14.0-cp313-cp313-win_amd64.whl (940 kB)
#    ---------------------------------------- 0.0/940.9 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/940.9 kB ? eta -:--:--
#    --------------------------------- ------ 786.4/940.9 kB 1.8 MB/s eta 0:00:01
#    ---------------------------------------- 940.9/940.9 kB 1.9 MB/s eta 0:00:00
# Installing collected packages: jiter, tiktoken, openai, langchain-openai
#
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    ------------------------------ --------- 3/4 [langchain-openai]
#    ---------------------------------------- 4/4 [langchain-openai]
#
# Successfully installed jiter-0.17.0 langchain-openai-1.6.2 openai-3.16.1 tiktoken-0.14.0

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    openai_api_key = API_KEY_OPENAI,
    model = "GPT-6 ASTRA",
    temperature = 0.1,
    max_tokens = 1024
)

# %%
# generate our retrieval - augmented output
def generate_output(query,retriever,llm,top_k=3):
    results = retriever.retrieve(query,top_k)

    context = "\n".join([doc["document"] for doc in results]) if results else""

    if not context:
        print("we found no relevent context from the given query")

    # context + query

    prompt = f""" use given context to generate the answer the answer for the query
                Context : {context}
                Query : {query}  """

    response = llm.invoke(prompt) # expecting a string as propmt , invoke is used for after sending req get res from llm

    return response.content

# %%
answer = generate_output("what is encoder-decoder?",rag_retriever,llm)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 answer = generate_output("what is encoder-decoder?",rag_retriever,llm)
#
# NameError: name 'rag_retriever' is not defined

# %%
print(answer)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(answer)
#
# NameError: name 'answer' is not defined

# %%
API_KEY_OPENAI = ""

# %%
# !pip install langchain-groq
# Out:
# Collecting langchain-groq
#   Using cached langchain_groq-1.1.3-py3-none-any.whl.metadata (2.9 kB)
# Collecting groq<1.0.0,>=0.30.0 (from langchain-groq)
#   Using cached groq-0.37.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in d:\users\rahul\anaconda3\lib\site-packages (from langchain-groq) (1.6.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in d:\users\rahul\anaconda3\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (4.15.1)
# Requirement already satisfied: distro<2,>=1.7.0 in d:\users\rahul\anaconda3\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\users\rahul\anaconda3\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in d:\users\rahul\anaconda3\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (2.10.3)
# Requirement already satisfied: sniffio in d:\users\rahul\anaconda3\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (1.3.0)
# Requirement already satisfied: typing-extensions<5,>=4.10 in d:\users\rahul\anaconda3\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (4.16.0)
# Requirement already satisfied: idna>=2.8 in d:\users\rahul\anaconda3\lib\site-packages (from anyio<5,>=3.5.0->groq<1.0.0,>=0.30.0->langchain-groq) (3.19)
# Requirement already satisfied: certifi in d:\users\rahul\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in d:\users\rahul\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in d:\users\rahul\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in d:\users\rahul\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-groq) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in d:\users\rahul\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-groq) (0.0.19)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in d:\users\rahul\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-groq) (0.12.6)
# Requirement already satisfied: packaging>=23.2.0 in d:\users\rahul\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-groq) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in d:\users\rahul\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-groq) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\users\rahul\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-groq) (9.0.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in d:\users\rahul\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-groq) (0.17.1)
# Requirement already satisfied: jsonpointer>=1.9 in d:\users\rahul\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain-groq) (2.1)
# Requirement already satisfied: httpx2<3,>=2 in d:\users\rahul\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (2.13.0)
# Requirement already satisfied: orjson>=3.9.14 in d:\users\rahul\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (3.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\users\rahul\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in d:\users\rahul\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (2.34.2)
# Requirement already satisfied: websockets>=15.0 in d:\users\rahul\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (16.1.1)
# Requirement already satisfied: xxhash>=3.0.0 in d:\users\rahul\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (4.0.1)
# Requirement already satisfied: zstandard>=0.23.0 in d:\users\rahul\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (0.23.0)
# Requirement already satisfied: httpcore2==2.13.0 in d:\users\rahul\anaconda3\lib\site-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (2.13.0)
# Requirement already satisfied: truststore>=0.10 in d:\users\rahul\anaconda3\lib\site-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (0.10.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\users\rahul\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in d:\users\rahul\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq) (2.27.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\users\rahul\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.26 in d:\users\rahul\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (2.3.0)
# Using cached langchain_groq-1.1.3-py3-none-any.whl (20 kB)
# Using cached groq-0.37.1-py3-none-any.whl (137 kB)
# Installing collected packages: groq, langchain-groq
#
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 2/2 [langchain-groq]
#
# Successfully installed groq-0.37.1 langchain-groq-1.1.3

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    groq_api_key = API_KEY_OPENAI,
    model = "qwen/qwen3-32b",
    tempereture = 0.1,
    max_tokens = 1024
)
# Out:
# d:\Users\rahul\anaconda3\Lib\site-packages\pydantic\main.py:214: UserWarning: WARNING! tempereture is not default parameter.
#                     tempereture was transferred to model_kwargs.
#                     Please confirm that tempereture is what you intended.
#   validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)

# %%
# generate our retrieval-augmented output
def generate_output(query, retriever, llm, top_k=3):
    results = retriever.retrieve(query, top_k)

    context = "\n".join([doc["document"] for doc in results]) if results else ""

    if not context:
        print("we found no relevant context for the given query")

    # context + query
    prompt = f""" use given context to generate the answer for the query
                Context: {context}
                Query: {query} """

    response = llm.invoke([prompt.format(context=context, query=query)]) # expecting a list as prompt
    return response.content

# %%
answer = generate_output("what is RAG?", rag_retriever, llm)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 answer = generate_output("what is RAG?", rag_retriever, llm)
#
# NameError: name 'rag_retriever' is not defined

# %%
print(answer)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 print(answer)
#
# NameError: name 'answer' is not defined
